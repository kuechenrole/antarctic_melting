# %%
import xarray as xr
import matplotlib.pyplot as plt
import os
import sys
import numpy as np
import pandas as pd
import scipy.io as sio

proj_dir = os.path.join(os.pardir,os.pardir)
data_dir = os.path.join(proj_dir,'data')

src_dir = os.path.join(proj_dir,'src')
sys.path.append(src_dir)

from tools.log_progress import log_progress

# %%
grid_path = os.path.join(data_dir,'preprocessing','processed','waom2_grd.nc')
grd = xr.open_dataset(grid_path)

# %%
shelves_path = os.path.join(data_dir,'analysis','interim','shelves2.npy')
shelves = np.load(shelves_path).item()

# %%
# %matplotlib notebook

plt.close()
fig,ax = plt.subplots(figsize=(10,7))
grd.zice.where((grd.mask_rho==1)&(grd.zice<0)).plot(ax=ax,alpha=0.5,add_colorbar=False)

for name,data in log_progress(ice_shelves.items()):
    
    grd.zice.where(data['mask']).plot(ax=ax,add_colorbar=False)
    ax.text(data['xi_mid'],data['eta_mid'],name)
    
    mask = data['mask']
    ax.contour(mask, colors=('black'),linewidths=0.5)
    
ax.set_aspect('equal')
plt.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ...
# /home/ubuntu/bigStick/anaconda3/envs/antarctic_melting/lib/python3.6/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %% [raw]
# coords_path = os.path.join(data_dir,'analysis','external','antbounds','shelves2.mat')
# coords = sio.loadmat(coords_path)['shelves'][0].squeeze()
#
# ice_shelves = {}
# for idx in range(np.size(coords)):
#     name = coords[idx][0][0]
#     ice_shelves[name]={}
#     ice_shelves[name]['lat']= coords[idx][1].squeeze()
#     ice_shelves[name]['lon']= coords[idx][2].squeeze()

# %% [raw]
# names = ['Wilkins','Abbot','Filchner', 'Ronne','Shackleton','Britten','Brahms','Amery','West','Ross East','Ross West']
# ice_shelves = { key:value for key,value in ice_shelves.items() if key in names}

# %% [raw]
# from scipy.spatial import KDTree
#
# lat_flat = grd.lat_rho.stack(etaxi = ('eta_rho','xi_rho'))
# lon_flat = grd.lon_rho.stack(etaxi = ('eta_rho','xi_rho'))
# points = np.column_stack((lat_flat.values,lon_flat.values))
# tree = KDTree(points)
#
# for name,data in log_progress(ice_shelves.items(),name='ice shelf'):
#
#     lats = data['lat']
#     lons = data['lon']
#
#     target = np.column_stack((lats,lons))
#     dist, ind = tree.query(target,k=1)
#
#     ice_shelves[name]['eta'] = lat_flat[np.unique(ind)].eta_rho.values
#     ice_shelves[name]['xi'] = lat_flat[np.unique(ind)].xi_rho.values

# %% [raw]
# from scipy import ndimage
# from skimage import io, morphology, img_as_bool, segmentation
# from scipy import ndimage as ndi
#
# for name,data in ice_shelves.items():
#
#     mask_tmp = np.zeros_like(grd.mask_rho.values)
#
#     eta = data['eta']
#     xi = data['xi']
#
#     mask_tmp[eta,xi] = 1
#     mask_tmp = (mask_tmp == 1)
#
#
#     #mask_tmp = ndi.distance_transform_edt(~mask_tmp)
#     #mask_tmp = mask_tmp < 1.0001
#     #mask_tmp = ndimage.binary_fill_holes(mask_tmp)
#     #mask_tmp = ndimage.binary_closing(mask_tmp,structure=fill)
#
#     xi_m,eta_m = np.median(xi),np.median(eta)
#
#     ice_shelves[name]['mask']=mask_tmp
#     ice_shelves[name]['xi_mid']=xi_m
#     ice_shelves[name]['eta_mid']=eta_m
