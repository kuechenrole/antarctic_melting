# %%
import os
import sys
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import cmocean.cm as ocm

proj_dir = os.path.join(os.pardir,os.pardir)
data_dir = os.path.join(proj_dir,'data','analysis')
int_dir = os.path.join(data_dir,'interim')

# %%
#load grid
#grd_path = os.path.join(int_dir,'grd2_dV.nc')
grd_path = os.path.join(int_dir,'grd4_dV.nc')
grd = xr.open_dataset(grd_path)

# %%
(grd.z[30]*-1).plot(cmap=ocm.deep,size=10)

# %%
diff = (grd.zice-grd.z[30]).where(grd.zice<0)

# %%
diff.mean()
# Out:
# <xarray.DataArray ()>
# array(3.033728)
